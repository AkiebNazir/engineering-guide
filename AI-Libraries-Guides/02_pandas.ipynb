# %%
import pandas as pd

df = pd.DataFrame({
    "name": ["Shahida", "Akieb", "Aasif", "Jamid"],
    "age": [33, 30, 27, 25],
    "education": ["12th", "Master's", "Bachler's", "BA"]
})

# %%
df["age"] > 30
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# Name: age, dtype: bool

# %%
df[df["age"] > 30]
# Out:
#       name  age education
# 0  Shahida   33      12th
